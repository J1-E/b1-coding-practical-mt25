# %%
# Add relevant Jupyter notebook extensions

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['/Library/Frameworks/Python.framework/Versions/3.12/lib/python312.zip', '/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12', '/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/lib-dynload', '', '/Users/joshejovi/Git Repo/practical/.venv/lib/python3.12/site-packages', '/Users/joshejovi/Git Repo/practical']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
from uuv_mission.dynamic import Submarine, ClosedLoop, Mission
from uuv_mission.control import Controller

sub = Submarine()
# Instantiate your controller (depending on your implementation)
mission = Mission.from_csv("/Users/joshejovi/GitRepo/practical/data/mission.csv") # You must implement this method in the Mission class
controller = Controller(sub, mission, Kp = 2.2, Kd = 2.55, Ki = 0.325) 
closed_loop = ClosedLoop(sub, controller)
trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
